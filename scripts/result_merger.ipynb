# %%
import pandas as pd

df0 = pd.read_csv("../output/submission_0.csv")
df1 = pd.read_csv("../output/submission_1.csv")
df2 = pd.read_csv("../output/submission_2.csv")
df3 = pd.read_csv("../output/submission_3.csv")
df4 = pd.read_csv("../output/submission_4.csv")
df5 = pd.read_csv("../output/submission_5.csv")
df6 = pd.read_csv("../output/submission_6.csv")
df7 = pd.read_csv("../output/submission_7.csv")
df8 = pd.read_csv("../output/submission_8.csv")
df9 = pd.read_csv("../output/submission_9.csv")

# %%
import pandas as pd

# Merge all dataframes vertically (stack rows)
result = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9], ignore_index=True)
result.rename(columns={'id': 'qid'}, inplace=True)
result.to_csv("../output/submission_0_9_L2.csv", index=False)

# %%
result
# Out:
#            qid answer
# 0    test_0001      A
# 1    test_0002      C
# 2    test_0003      A
# 3    test_0004      B
# 4    test_0005      B
# ..         ...    ...
# 365  test_0366      B
# 366  test_0367      B
# 367  test_0368      B
# 368  test_0369      B
# 369  test_0370      A
#
# [370 rows x 2 columns]
